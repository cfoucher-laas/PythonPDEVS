# %% [markdown]
# # PythonPDEVS examples

# %% [markdown]
# Import PythonPDEVS modelling elements for *AtomicDEVS* and *CoupledDEVS* models.
# Also import the concept of *INFINITY* to be used.

# %%
from pypdevs.DEVS import AtomicDEVS, CoupledDEVS
from pypdevs.infinity import INFINITY

# %% [markdown]
# Create some simple *AtomicDEVS* models for a *Generator* and a *Queue*.

# %%
class Generator(AtomicDEVS):
    def __init__(self):
        AtomicDEVS.__init__(self, "Generator")
        self.state = 0
        self.outport = self.addOutPort("outport")

    def timeAdvance(self):
        return 1.0

    def outputFnc(self):
        # Our message is simply the integer 5, though this could be anything
        return {self.outport: 5}

    def intTransition(self):
        return self.state + 1

# %%
class Queue(AtomicDEVS):
    def __init__(self):
        AtomicDEVS.__init__(self, "Queue")
        self.state = None
        self.processing_time = 1.0
        self.inport = self.addInPort("input")
        self.outport = self.addOutPort("output")

    def timeAdvance(self):
        if self.state is None:
            return INFINITY
        else:
            return self.processing_time

    def outputFnc(self):
        return {self.outport: self.state}

    def extTransition(self, inputs):
        self.state = inputs[self.inport]
        return self.state

    def intTransition(self):
        return None

# %% [markdown]
# Add the Coupled DEVS model for a simple *CoupledQueue*.

# %%
class CQueue(CoupledDEVS):
    def __init__(self):
        CoupledDEVS.__init__(self, "CQueue")
        self.generator = self.addSubModel(Generator())
        self.queue = self.addSubModel(Queue())
        self.connectPorts(self.generator.outport, self.queue.inport)
    
    def select(self, imm):
        return self.queue

# %% [markdown]
# Finally run the simulation by setting up an experiment file as follows.
# First, however, we have to include the simulator concept.

# %%
from pypdevs.simulator import Simulator

# %%
model = CQueue()
sim = Simulator(model)
# Required to set Classic DEVS, as we simulate in Parallel DEVS otherwise
sim.setClassicDEVS()
sim.setTerminationTime(10.0)
sim.simulate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d8104c9df385> in <module>()
#       4 sim.setClassicDEVS()
#       5 sim.setTerminationTime(10.0)
# ----> 6 sim.simulate()
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/simulator.py in simulate(self)
#     612             self.checkpoint()
#     613
# --> 614         self.real_simulate()
#     615
#     616     def removeTracers(self):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/simulator.py in real_simulate(self)
#     729                 # Simply do a blocking call, thus preventing the finish ring algorithm
#     730                 #begin = time.time()
# --> 731                 self.controller.getProxy(locations[0]).simulate_sync()
#     732                 #print(time.time() - begin)
#     733             else:
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/MPIRedirect.py in localcall(*args, **kwargs)
#     224             A call to a local location
#     225             """
# --> 226             return LocalRedirect.localCall(self, name, *args, **kwargs)
#     227         return localcall
#     228
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/MPIRedirect.py in localCall(self, method, *args, **kwargs)
#     200             threading.Thread(target=func, args=args, kwargs=kwargs).start()
#     201         else:
# --> 202             return func(*args, **kwargs)
#     203
#     204     def __init__(self, server):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/controller.py in simulate_sync(self)
#     172         Synchronous simulation call, identical to the normal call, with the exception that it will be a blocking call as only "simulate" is marked as oneway.
#     173         """
# --> 174         BaseSimulator.simulate_sync(self)
#     175         self.no_finish_ring.acquire()
#     176
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in simulate_sync(self)
#    1299         A small wrapper around the simulate() function, though with a different name to allow a much simpler MPI one way check
#    1300         """
# -> 1301         self.simulate()
#    1302
#    1303     def simulate(self):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/controller.py in simulate(self)
#     185             visualizeLocations(self)
#     186         # Call superclass (the actual simulation)
# --> 187         BaseSimulator.simulate(self)
#     188         self.prev_termination_time = self.termination_time[0]
#     189
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in simulate(self)
#    1328
#    1329         while 1:
# -> 1330             self.runsim()
#    1331             if self.irreversible:
#    1332                 self.should_run.clear()
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in runsim(self)
#    1168                 # Don't interrupt the output generation, as these nodes WILL be marked as 'sent'
#    1169                 with self.Vlock:
# -> 1170                     reschedule = self.coupledOutputGeneration(self.current_clock)
#    1171                 try:
#    1172                     self.massAtomicTransitions(self.transitioning, self.current_clock)
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/solver.py in coupledOutputGenerationClassic(self, time)
#     256         if len(imminent) > 1:
#     257             # Perform all selects
# --> 258             imminent.sort()
#     259             pending = imminent
#     260             level = 1
#
# TypeError: unorderable types: Queue() < Generator()

# %% [markdown]
# Simulation is now done, and the results can be seen in the changed states of the model.

# %%
model.generator.state
# Out:
# 1

# %% [markdown]
# Another option is to use verbose simulation, as follows.

# %%
model = CQueue()
sim = Simulator(model)
sim.setVerbose()
# Required to set Classic DEVS, as we simulate in Parallel DEVS otherwise
sim.setClassicDEVS()
sim.setTerminationTime(10.0)
sim.simulate()
# Out:
# __  Current Time:       0.00 __________________________________________
#
#
# 	INITIAL CONDITIONS in model <CQueue.Generator>
# 		Initial State: 0
# 		Next scheduled internal transition at time 1.00
#
#
# 	INITIAL CONDITIONS in model <CQueue.Queue>
# 		Initial State: None
# 		Next scheduled internal transition at time inf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-11bc5317f357> in <module>()
#       5 sim.setClassicDEVS()
#       6 sim.setTerminationTime(10.0)
# ----> 7 sim.simulate()
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/simulator.py in simulate(self)
#     612             self.checkpoint()
#     613
# --> 614         self.real_simulate()
#     615
#     616     def removeTracers(self):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/simulator.py in real_simulate(self)
#     729                 # Simply do a blocking call, thus preventing the finish ring algorithm
#     730                 #begin = time.time()
# --> 731                 self.controller.getProxy(locations[0]).simulate_sync()
#     732                 #print(time.time() - begin)
#     733             else:
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/MPIRedirect.py in localcall(*args, **kwargs)
#     224             A call to a local location
#     225             """
# --> 226             return LocalRedirect.localCall(self, name, *args, **kwargs)
#     227         return localcall
#     228
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/MPIRedirect.py in localCall(self, method, *args, **kwargs)
#     200             threading.Thread(target=func, args=args, kwargs=kwargs).start()
#     201         else:
# --> 202             return func(*args, **kwargs)
#     203
#     204     def __init__(self, server):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/controller.py in simulate_sync(self)
#     172         Synchronous simulation call, identical to the normal call, with the exception that it will be a blocking call as only "simulate" is marked as oneway.
#     173         """
# --> 174         BaseSimulator.simulate_sync(self)
#     175         self.no_finish_ring.acquire()
#     176
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in simulate_sync(self)
#    1299         A small wrapper around the simulate() function, though with a different name to allow a much simpler MPI one way check
#    1300         """
# -> 1301         self.simulate()
#    1302
#    1303     def simulate(self):
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/controller.py in simulate(self)
#     185             visualizeLocations(self)
#     186         # Call superclass (the actual simulation)
# --> 187         BaseSimulator.simulate(self)
#     188         self.prev_termination_time = self.termination_time[0]
#     189
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in simulate(self)
#    1328
#    1329         while 1:
# -> 1330             self.runsim()
#    1331             if self.irreversible:
#    1332                 self.should_run.clear()
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/basesimulator.py in runsim(self)
#    1168                 # Don't interrupt the output generation, as these nodes WILL be marked as 'sent'
#    1169                 with self.Vlock:
# -> 1170                     reschedule = self.coupledOutputGeneration(self.current_clock)
#    1171                 try:
#    1172                     self.massAtomicTransitions(self.transitioning, self.current_clock)
#
# ~/.local/lib64/python3.5/site-packages/pypdevs/solver.py in coupledOutputGenerationClassic(self, time)
#     256         if len(imminent) > 1:
#     257             # Perform all selects
# --> 258             imminent.sort()
#     259             pending = imminent
#     260             level = 1
#
# TypeError: unorderable types: Queue() < Generator()

# %% [markdown]
# Apart from Classic DEVS simulation, Parallel DEVS simulation is also possible.bag
# For this, we add a slightly altered version of the models, to comply with bag semantics.

# %%
class Generator(AtomicDEVS):
    def __init__(self):
        AtomicDEVS.__init__(self, "Generator")
        self.state = 0
        self.outport = self.addOutPort("outport")

    def timeAdvance(self):
        return 1.0

    def outputFnc(self):
        # Our message is simply the integer 5, though this could be anything
        return {self.outport: [5]}

    def intTransition(self):
        return self.state + 1
    
class Queue(AtomicDEVS):
    def __init__(self):
        AtomicDEVS.__init__(self, "Queue")
        self.state = None
        self.processing_time = 1.0
        self.inport = self.addInPort("input")
        self.outport = self.addOutPort("output")

    def timeAdvance(self):
        if self.state is None:
            return INFINITY
        else:
            return self.processing_time

    def outputFnc(self):
        return {self.outport: [self.state]}

    def extTransition(self, inputs):
        self.state = inputs[self.inport][0]
        return self.state

    def intTransition(self):
        self.state = None
        return self.state

# %% [markdown]
# And similar to before, we start the experiment, now not using the *setClassicDEVS* option.

# %%
model = CQueue()
sim = Simulator(model)
sim.setVerbose()
sim.setTerminationTime(10.0)
sim.simulate()
# Out:
# __  Current Time:       0.00 __________________________________________
#
#
# 	INITIAL CONDITIONS in model <CQueue.Generator>
# 		Initial State: 0
# 		Next scheduled internal transition at time 1.00
#
#
# 	INITIAL CONDITIONS in model <CQueue.Queue>
# 		Initial State: None
# 		Next scheduled internal transition at time inf
#
#
# __  Current Time:       1.00 __________________________________________
#
#
# 	EXTERNAL TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Next scheduled internal transition at time 2.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 1
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 2.00
#
#
# __  Current Time:       2.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 3.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 2
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 3.00
#
#
# __  Current Time:       3.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 4.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 3
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 4.00
#
#
# __  Current Time:       4.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 5.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 4
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 5.00
#
#
# __  Current Time:       5.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 6.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 5
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 6.00
#
#
# __  Current Time:       6.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 7.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 6
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 7.00
#
#
# __  Current Time:       7.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 8.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 7
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 8.00
#
#
# __  Current Time:       8.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 9.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 8
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 9.00
#
#
# __  Current Time:       9.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 10.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 9
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 10.00
#
#
# __  Current Time:      10.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 11.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 10
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 11.00

# %% [markdown]
# A termination condition can also be used.

# %%
def termFunc(clock, model):
    if model.generator.state > 5:
        # The generator has generated more than 5 events
        # So stop
        return True
    elif clock[0] > 10:
        # Or if the clock has progressed past simulation time 10
        return True
    else:
        # Otherwise, we simply continue
        return False

# %%
model = CQueue()
sim = Simulator(model)
sim.setVerbose()
sim.setTerminationCondition(termFunc)
sim.simulate()
# Out:
# __  Current Time:       0.00 __________________________________________
#
#
# 	INITIAL CONDITIONS in model <CQueue.Generator>
# 		Initial State: 0
# 		Next scheduled internal transition at time 1.00
#
#
# 	INITIAL CONDITIONS in model <CQueue.Queue>
# 		Initial State: None
# 		Next scheduled internal transition at time inf
#
#
# __  Current Time:       1.00 __________________________________________
#
#
# 	EXTERNAL TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Next scheduled internal transition at time 2.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 1
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 2.00
#
#
# __  Current Time:       2.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 3.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 2
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 3.00
#
#
# __  Current Time:       3.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 4.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 3
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 4.00
#
#
# __  Current Time:       4.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 5.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 4
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 5.00
#
#
# __  Current Time:       5.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 6.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 5
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 6.00
#
#
# __  Current Time:       6.00 __________________________________________
#
#
# 	CONFLUENT TRANSITION in model <CQueue.Queue>
# 		Input Port Configuration:
# 			port <input>:
# 				5
# 		New State: 5
# 		Output Port Configuration:
# 			port <output>:
# 				5
# 		Next scheduled internal transition at time 7.00
#
#
# 	INTERNAL TRANSITION in model <CQueue.Generator>
# 		New State: 6
# 		Output Port Configuration:
# 			port <outport>:
# 				5
# 		Next scheduled internal transition at time 7.00
